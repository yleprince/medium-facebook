# %% [markdown]
# # Context Analysis
#
# Up to date data can be downloaded here: [Google Trends](https://trends.google.com/trends/explore?date=all&q=%2Fm%2F02y1vz)

# %%
import pandas as pd

from utils import google_trends, load_gtrends
from utils import world_proportions
# Out:
# /home/yperso/.cache/pypoetry/virtualenvs/facebook-LxVRUW1A-py3.8/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
PATH = '../data/processed/'

world = load_gtrends(f"{PATH}facebook_gtrends_world.csv")
france = load_gtrends(f"{PATH}facebook_gtrends_france.csv")
usa = load_gtrends(f"{PATH}facebook_gtrends_usa.csv")

google_trends(france, usa, world)

# %%
world_proportions()
